# %%
4students = []

def show_menu():
    print("\n====== Student Management System ======")
    print("1. Add Student")
    print("2. View All Students")
    print("3. Search Student")
    print("4. Delete Student")
    print("5. Exit")
    print("======================================")

def add_student():
    print("\n--- Add New Student ---")
    name = input("Enter student name: ")
    age = input("Enter age: ")
    roll_no = input("Enter roll number: ")
    course = input("Enter course: ")

    student = {
        "name": name,
        "age": age,
        "roll_no": roll_no,
        "course": course
    }

    students.append(student)
    print("✅ Student added successfully!")

def view_students():
    print("\n--- Student List ---")
    if not students:
        print("No records found!")
        return
    for idx, student in enumerate(students, start=1):
        print(f"{idx}. Name: {student['name']}, Age: {student['age']}, Roll No: {student['roll_no']}, Course: {student['course']}")

def search_student():
    print("\n--- Search Student ---")
    roll_no = input("Enter roll number to search: ")
    found = False
    for student in students:
        if student['roll_no'] == roll_no:
            print(f"✅ Found: Name: {student['name']}, Age: {student['age']}, Roll No: {student['roll_no']}, Course: {student['course']}")
            found = True
            break
    if not found:
        print("❌ Student not found!")

def delete_student():
    print("\n--- Delete Student ---")
    roll_no = input("Enter roll number to delete: ")
    for student in students:
        if student['roll_no'] == roll_no:
            students.remove(student)
            print("✅ Student deleted successfully!")
            return
    print("❌ Student not found!")

# Main program loop
while True:
    show_menu()
    choice = input("Enter your choice (1-5): ")

    if choice == "1":
        add_student()
    elif choice == "2":
        view_students()
    elif choice == "3":
        search_student()
    elif choice == "4":
        delete_student()
    elif choice == "5":
        print("👋 Exiting program. Goodbye!")
        break
    else:
        print("❌ Invalid choice! Please enter 1-5.")
# Out:
# ====== Student Management System ======
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# ======================================
# Enter your choice (1-5): 1
#
# --- Add New Student ---
# Enter student name: shareef
# Enter age: 23
# Enter roll number: 10
# Enter course: Data Science
# ✅ Student added successfully!
#
# ====== Student Management System ======
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# ======================================
# Enter your choice (1-5): 3
#
# --- Search Student ---
# Enter roll number to search: 10
# ✅ Found: Name: shareef, Age: 23, Roll No: 10, Course: Data Science
#
# ====== Student Management System ======
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# ======================================
# Enter your choice (1-5): 1
#
# --- Add New Student ---
# Enter student name: 1
# Enter age: 23
# Enter roll number: 11
# Enter course: Data Science
# ✅ Student added successfully!
#
# ====== Student Management System ======
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# ======================================
# Enter your choice (1-5): 1
#
# --- Add New Student ---
# Enter student name: nitha
# Enter age: 22
# Enter roll number: 04
# Enter course: Data Analytics
# ✅ Student added successfully!
#
# ====== Student Management System ======
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# ======================================
# Enter your choice (1-5): 2
#
# --- Student List ---
# 1. Name: shareef, Age: 23, Roll No: 10, Course: Data Science
# 2. Name: 1, Age: 23, Roll No: 11, Course: Data Science
# 3. Name: nitha, Age: 22, Roll No: 04, Course: Data Analytics
#
# ====== Student Management System ======
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# ======================================
# Enter your choice (1-5):
# ❌ Invalid choice! Please enter 1-5.
#
# ====== Student Management System ======
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# ======================================
# Enter your choice (1-5): 4
#
# --- Delete Student ---
# Enter roll number to delete: 11
# ✅ Student deleted successfully!
#
# ====== Student Management System ======
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# ======================================
# Enter your choice (1-5): 2
#
# --- Student List ---
# 1. Name: shareef, Age: 23, Roll No: 10, Course: Data Science
# 2. Name: nitha, Age: 22, Roll No: 04, Course: Data Analytics
#
# ====== Student Management System ======
# 1. Add Student
# 2. View All Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# ======================================
